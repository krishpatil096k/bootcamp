# %%
import random

# Generate a list of 10 random numbers between 1 and 100
random_numbers = [random.randint(1, 100) for _ in range(10)]

# Filter and print even numbers
even_numbers = [num for num in random_numbers if num % 2 == 0]

print("Random Numbers:", random_numbers)
print("Even Numbers:", even_numbers)
# Out:
# Random Numbers: [96, 65, 22, 84, 67, 46, 80, 22, 32, 87]
# Even Numbers: [96, 22, 84, 46, 80, 22, 32]

# %%
 
text = "I am the student of iceem"

 
reversed_string = text[::-1]

 
reversed_words = " ".join(text.split()[::-1])

print("Original String:", text)
print("Reversed String:", reversed_string)
print("Reversed Words:", reversed_words)
# Out:
# Original String: I am the student of iceem
# Reversed String: meeci fo tneduts eht ma I
# Reversed Words: iceem of student the am I
